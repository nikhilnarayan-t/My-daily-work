# %%
# DAY 1
#1
print("hello, world")
# Out:
# hello, world

# %%
#2
# input("what's your name?")
# Out:
# 'Nikhil'

# %%
#3
name=input("what's your name?")
print("hello")
print(name)
# Out:
# hello
# Nikhil!

# %%
#4
name=input("what's your name?")
print("hello, " + name)
# Out:
# hello, nikhil

# %%
#DAY 2

# %%
#5
name=input("whats your name?")
print(f"hello, " + name)
# Out:
# hello, Nikhil

# %%
#6
#to remove space from string
name=input("what's your name?")
#removing space
name=name.strip()
print(f"hello, " + name)
# Out:
# hello, Nikhil

# %%
#7
name=input("what's your name?")
#capitalize()
name=name.capitalize()
print(f"hello ," + name)
# Out:
# hello ,Nikhil

# %%
#8
name=input("what's your name?")
#title()
name=name.title()
print(f"hello, " + name)
# Out:
# hello, Nikhil Narayana

# %%
#9
#int
x=7
y=5
z=x+y
print(z)
# Out:
# 12

# %%
#10
#taking input from user
x=input("x=?")
y=input("y=?")
z=int(x)+int(y)
print(y)
# Out:
# 76

# %%
#11
x=int(input("x=?"))
y=int(input("y=?"))
print(x+y)
# Out:
# 91

# %%
#12
#float
x=float(input("x=?"))
y=float(input("y=?"))
print(x+y)
# Out:
# 8.7

# %%
#13
#roundoff
x=float(input("x=?"))
y=float(input("y=?"))
z=round(x+y)
print(z)
# Out:
# 9

# %%
#14
x=float(input("x=?"))
y=float(input("y=?"))
z=x/y
print(f"{z:.2f}")
# Out:
# 1.12

# %%
#DAY3
#15
def hello():
    print("hello")
name=input("whats your name?")
hello()
print(name)
# Out:
# hello
# nikhil

# %%
#16
def hello(to):
    print("hello ,", to)
name=input("whats your name? ")
hello(name)
# Out:
# hello , nikhil

# %%
#17
def hello(to="world"):
    print("hello ,", to)
hello()
n=input("ur name? ")
hello(n)
# Out:
# hello , world
# hello , sneha

# %%
#18
def main():
    x=int(input("x=?"))
    print(" x squared is:", squared(x))

def squared(n):
    return n*n
main()
# Out:
#  x squared is: 16

# %%
#19
x=int(input("x=?"))
y=int(input("y=?"))
if x>y:
    print("x is greater than y")
elif x<y:
    print("x is less than y")
else:
    print("x is equal to y")
# Out:
# x is less than y

# %%
#20
x=int(input("x=?"))
y=int(input("y=?"))

if x<y or x>y:
    print("x is not equal to y")
else:
    print("x is equal to y")
# Out:
# x is equal to y

# %%
#DAY5
#21
score=int(input("score?"))

if score>=90 and score<=100:
    print("grade A")
elif score>=80 and score<90:
    print("grade B")
elif score>=70 and score<80:
    print("grade C")
elif score>=60 and score<70:
    print("grade D")
else:
    print("grade F")
# Out:
# grade C

# %%
#22
#another way
score=int(input("score?"))

if 90 <= score <=100:
    print("grade A")
elif 80 <= score <90:
    print("grade B")
elif 70 <= score <80:
    print("grade C")
elif 60 <= score <70:
    print("grade D")
else:
    print("grade F")
# Out:
# grade A

# %%
#23
#another way
score=int(input("score?"))

if score>=90:
    print("grade A")
elif score>=80:
    print("grade B")
elif score>=70:
    print("grade C")
elif score>=60:
    print("grade D")
else:
    print("grade F")
# Out:
# grade F

# %%
#24
x=int(input("x=?"))

if x%2==0:
    print("x is even")
else:
    print("x is odd")
# Out:
# x is odd

# %%
#25
def main():
    x=int(input("x=?"))
    if is_even(x):
        print("x is even")
    else:
        print("x is odd")

def is_even(n):
    if n%2==0:
        return True
    else:
        return False
main()
# Out:
# x is even

# %%
#26
#anothey short way
def main():
    x = int(input("x=?"))
    if is_even(x):
        print("x is even")
    else:
        print("x is odd")


def is_even(n):
    return True if n%2==0 else False



main()
# Out:
# x is even

# %%
#27
#another way

def main():
    x = int(input("x=?"))
    if is_even(x):
        print("x is even")
    else:
        print("x is odd")


def is_even(n):
    return n%2==0

main()
# Out:
# x is even

# %%
#28
name=input("what's your name?")

if  name=="Harry" or name=="hero" or name=="ron":
    print("match")
else:
    print("who?")

# %%
#Day6

# %%
#while
#29
i=3
while i!=0:
    print("man")
    i=i-1
# Out:
# man
# man
# man

# %%
#30
i=1
while i<=3:
    print("sneha")
    i=i+1
# Out:
# sneha
# sneha
# sneha

# %%
#31
i=0
while i<3:
    print("nikhil")
    i+=1
# Out:
# nikhil
# nikhil
# nikhil

# %%
#32
for i in range(3):
    print("thank you")
# Out:
# thank you
# thank you
# thank you

# %%
#33
for i in [1,2,3]:
    print("hello")
# Out:
# hello
# hello
# hello

# %%
#34
print("Nikhil\n" *4, end="")
# Out:
# Nikhil
# Nikhil
# Nikhil
# Nikhil

# %%
#35
while True:
    n=int(input("n="))
    if n<0:
        continue
    else:
        break

for _ in range(n):
    print("Python")
# Out:
# Python
# Python
# Python
# Python

# %%
#36
def main():
    nikhil(4)

def nikhil(n):
    for _ in range(n):
        print("nikhil")
main()
# Out:
# nikhil
# nikhil
# nikhil
# nikhil

# %%
#37
def main():
    number = get_number()
    sne(number)

def get_number():
    while True:
        n = int(input("n = "))
        if n > 0:
            return n

def sne(n):
    for _ in range(n):
        print("nikh")

main()
# Out:
# nikh
# nikh
# nikh
# nikh
# nikh

# %%
#38
students=["Nikhil","Sneha","Nikhil","Women","sneha"]
for student in students:
    print(student)
# Out:
# Nikhil
# Sneha
# Nikhil
# Women
# sneha

# %%
#39
students=["Nikhil","Sneha","Nikhil","Women","sneha"]

for i in range(len(students)):
    print(students[i])
    print(i+1,students[i])
# Out:
# Nikhil
# 1 Nikhil
# Sneha
# 2 Sneha
# Nikhil
# 3 Nikhil
# Women
# 4 Women
# sneha
# 5 sneha

# %%
#40
students={"Nikhil":"one",
          "Sneha":"two",
          "Women":"three",
          }
print(students)
print(students["Nikhil"])
print(students["Sneha"])
# Out:
# {'Nikhil': 'one', 'Sneha': 'two', 'Women': 'three'}
# one
# two

# %%
#41
students={"Nikhil":"one",
          "Sneha":"two",
          "Women":"three",
          }
for student in students:
    print(student,students[student], sep=", ")
# Out:
# Nikhil, one
# Sneha, two
# Women, three

# %%
#DAY7

# %%
#42
students=[
    {"name":"nikhil","house":"ecity","sports":"cricket"},
    {"name":"sneha","house":"dodballapura","sports":"badminton"},
    {"name":"dog","house":"earth","sports":"bark"},
    {"name":"human","house":"india","sports":None}
]
for student in students:
    print(student["name"], sep=", ")
# Out:
# nikhil
# sneha
# dog
# human

# %%
#43
students=[
    {"name":"nikhil","house":"ecity","sports":"cricket"},
    {"name":"sneha","house":"dodballapura","sports":"badminton"},
    {"name":"dog","house":"earth","sports":"bark"},
    {"name":"human","house":"india","sports":None}
]
for student in students:
    print(student["name"], student["house"], sep=", ")
# Out:
# nikhil, ecity
# sneha, dodballapura
# dog, earth
# human, india

# %%
#44
students=[
    {"name":"nikhil","house":"ecity","sports":"cricket"},
    {"name":"sneha","house":"dodballapura","sports":"badminton"},
    {"name":"dog","house":"earth","sports":"bark"},
    {"name":"human","house":"india","sports":None}
]
for student in students:
    print(student["name"], student["house"], student["sports"], sep=", ")
# Out:
# nikhil, ecity, cricket
# sneha, dodballapura, badminton
# dog, earth, bark
# human, india, None

# %%
#45
def main():
    print_square(3)

def print_square(size):
    for i in range(size):
        for j in range(size):
            print("#", end="")
        print()
main()
# Out:
# ###
# ###
# ###

# %%
#46
#without using columns#45
def main():
    print_square(3)

def print_square(size):
    for i in range(size):
        print("#" *size)
main()
# Out:
# ###
# ###
# ###

# %%
#DAY 9

# %%
#47

try:
    x=int(input("x=?"))
    print(f"x is {x}")
except valueError:
    print("X is not an integer")
# Out:
# x is 89

# %%
#48
try:
    x=int(input("x=?"))
except ValueError:
    print("X is not an integer")
else:
    print(f"x is {x}")
# Out:
# x is 3

# %%
#49
while True:
    try:
        x=int(input("x=?"))
    except ValueError:
        print("X is not an integer")
    else:
        break
print(f"x is {x}")
# Out:
# x is 3

# %%
#50
def main():
    x=get_int()
    print(f"x is {x}")

def get_int():
    while True:
        try:
            return int(input("x=?"))
        except ValueError:
            pass
main()
# Out:
# x is 4

# %%
#51
def main():
    x=get_int("what's x?")
    print(f"x is {x}")

def get_int(promt):
    while True:
        try:
            return int(input(promt))
        except ValueError:
            pass
main()
# Out:
# x is 3942384
