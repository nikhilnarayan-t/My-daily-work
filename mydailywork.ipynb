# %%
# DAY 1
#1
print("hello, world")
# Out:
# hello, world

# %%
#2
# input("what's your name?")
# Out:
# 'Nikhil'

# %%
#3
name=input("what's your name?")
print("hello")
print(name)
# Out:
# hello
# Nikhil!

# %%
#4
name=input("what's your name?")
print("hello, " + name)
# Out:
# hello, nikhil
